# %%
observation
# [cart_position, cart_velocity, pole_angle, pole_angular_velocity]
# Out:
# array([ 0.02608301, -0.00524092, -0.00364483, -0.03062244], dtype=float32)

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.spec.max_episode_steps
# Out:
# 500

# %%
env.spec.reward_threshold

# What does reward threshold really mean?
# Ok, so it basically means that atleast our agen should be able to hold the stick upright for 475 frames
# Out:
# 475.0

# %%
env.observation_space
# these are the limits for our observation space
# [low limit, high limit, num of fields, dtype]
# Out:
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %%
num_of_episodes = 10000
timeSteps=100
 
 
for episodeIndex in range(num_of_episodes):
    print(episodeIndex)
    initial_state=env.reset()
    env.render()
    appendedObservations=[]
    for timeIndex in range(timeSteps):
        print(timeIndex)
        random_action=env.action_space.sample()
        (observation, reward, terminated, truncated, info) = env.step(random_action)
        
        # just keep in mind what env.step returns back
        
        appendedObservations.append(observation)
        time.sleep(0.1)
        if (terminated):
            time.sleep(1)
            break
env.close()
# Out:
# 0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[33], line 7
#       3
#       4
#       5 for episodeIndex in range(num_of_episodes):
#       6     print(episodeIndex)
# ----> 7     initial_state=env.reset()
#       8     env.render()
#       9     appendedObservations=[]
#      10     for timeIndex in range(timeSteps):
#
# File ~/.local/lib/python3.14/site-packages/gymnasium/wrappers/common.py:145, in TimeLimit.reset(self, seed, options)
#     135 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#     136
#     137 Args:
#    (...)    142     The reset environment
#     143 """
#     144 self._elapsed_steps = 0
# --> 145 return super().reset(seed=seed, options=options)
#
# File ~/.local/lib/python3.14/site-packages/gymnasium/core.py:333, in Wrapper.reset(self, seed, options)
#     329 def reset(
# ...
